-- %% [markdown]
-- # Quality checks for 'Silver' layer

-- %% [markdown]
-- Script Purpose:<br>
--     This script performs various quality checks for data consistency, accuracy,
--     and standardization across the 'silver' layer. It includes checks for:<br>
--     - Null or duplicate primary keys.<br>
--     - Unwanted spaces in string fields.<br>
--     - Data standardization and consistency.<br>
--     - Invalid date ranges and orders.<br>
--     - Data consistency between related fields.
--
-- Usage Notes:
--     - Run these checks after data loading Silver Layer.
--     - Investigate and resolve any discrepancies found during the checks.

-- %% [markdown]
-- ## Checking `sales_project.silver.crm_cust_info`

-- %% [markdown]
-- #### Check for nulls or duplicates in primary key
-- Expectation: no results

-- %%
%sql
SELECT 
    cst_id,
    COUNT(*)
FROM 
    sales_project.silver.crm_cust_info
GROUP BY 
    cst_id
HAVING 
    COUNT(*) > 1 
    OR cst_id IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cst_id</th><th>COUNT(*)</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### Check for unwanted spaces
-- Expectation: no results

-- %%
SELECT 
    *
FROM 
    sales_project.silver.crm_cust_info
WHERE 
    cst_firstname != TRIM(cst_firstname) 
    OR cst_lastname != TRIM(cst_lastname);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cst_id</th><th>cst_key</th><th>cst_firstname</th><th>cst_lastname</th><th>cst_gndr</th><th>cst_marital_status</th><th>cst_create_date</th><th>dwh_create_date</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### Data standardization and consistency
-- Expectation: 'Married' and 'Single'

-- %%
SELECT
    DISTINCT cst_marital_status
FROM
    sales_project.silver.crm_cust_info;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cst_marital_status</th></tr></thead><tbody><tr><td>Married</td></tr><tr><td>Single</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Checking `sales_project.silver.crm_prd_info`

-- %% [markdown]
-- #### Check for nulls or duplicates in primary key
-- Expectation: no results

-- %%
%sql
SELECT 
    prd_id, COUNT(*)
FROM
    sales_project.silver.crm_prd_info
GROUP BY 
    prd_id
HAVING 
    COUNT(*) > 1 
    OR prd_id IS NULL;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_id</th><th>COUNT(*)</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### Check for unwanted spaces
-- Expectation: no results

-- %%
%sql
SELECT
    *
FROM 
    sales_project.silver.crm_prd_info
WHERE
    prd_nm != TRIM(prd_nm);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_id</th><th>cat_id</th><th>prd_key</th><th>prd_nm</th><th>prd_cost</th><th>prd_line</th><th>prd_start_dt</th><th>prd_end_dt</th><th>dwh_create_date</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### Check for nulls or negatives
-- Expectation: no results

-- %%
SELECT 
    *
FROM 
    sales_project.silver.crm_prd_info
WHERE 
    prd_cost IS NULL 
    OR prd_cost < 0;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_id</th><th>cat_id</th><th>prd_key</th><th>prd_nm</th><th>prd_cost</th><th>prd_line</th><th>prd_start_dt</th><th>prd_end_dt</th><th>dwh_create_date</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### Data standardization and consistency

-- %%
%sql
SELECT DISTINCT 
    prd_line 
FROM 
    sales_project.silver.crm_prd_info;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prd_line</th></tr></thead><tbody><tr><td>Mountain</td></tr><tr><td>Road</td></tr><tr><td>Other Sales</td></tr><tr><td>Touring</td></tr><tr><td>n/a</td></tr></tbody></table></div>

-- %% [markdown]
-- #### Check for Invalid Date Orders

-- %%
SELECT 
    * 
FROM 
    sales_project.silver.crm_prd_info
WHERE
    prd_end_dt < prd_start_dt;

-- %% [markdown]
-- ## Checking `sales_project.silver.crm_sales_details`

-- %% [markdown]
-- #### Check for Invalid Dates
-- Expectation: No Invalid Dates

-- %%
%sql
SELECT 
    NULLIF(sls_order_dt, 0) AS sls_order_dt 
FROM sales_project.bronze.crm_sales_details
WHERE sls_order_dt <= 0 
    OR LEN(sls_order_dt) != 8 
    OR sls_order_dt > 20500101 
    OR sls_order_dt < 19000101;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_order_dt</th></tr></thead><tbody><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>32154</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>5489</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr><tr><td>null</td></tr></tbody></table></div>

-- %% [markdown]
-- #### Check for Invalid Date Orders
-- Expectation: No Results

-- %%
%sql
SELECT
    *
FROM
    sales_project.silver.crm_sales_details
WHERE
    sls_order_dt > sls_ship_dt
    OR sls_ship_dt > sls_due_dt;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_ord_num</th><th>sls_prd_key</th><th>sls_cust_id</th><th>sls_order_dt</th><th>sls_ship_dt</th><th>sls_due_dt</th><th>sls_sales</th><th>sls_quantity</th><th>sls_price</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### Check Data Consistency: Sales = Quantity * Price
-- Expectation: No Results

-- %%
%sql
SELECT DISTINCT
    sls_sales, 
    sls_quantity, 
    sls_price
FROM
    sales_project.silver.crm_sales_details
WHERE
    sls_quantity * sls_price != sls_sales
    OR sls_sales <= 0
    OR sls_quantity <= 0
    OR sls_price <= 0
    OR sls_sales IS NULL
    OR sls_quantity IS NULL
    OR sls_price IS NULL
ORDER BY 
    sls_sales, 
    sls_quantity, 
    sls_price;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sls_sales</th><th>sls_quantity</th><th>sls_price</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- ## Checking `sales_project.bronze.erp_cust_az_12`

-- %%
%sql
SELECT *
FROM 
    sales_project.silver.erp_cust_az_12
WHERE 
    cid not like 'AW%';
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cid</th><th>bdate</th><th>gen</th><th>dwh_create_date</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### Identify out of range dates

-- %%
%sql
SELECT *
FROM 
    sales_project.silver.erp_cust_az_12
WHERE 
    bdate < '1930-01-01' 
    OR bdate > GETDATE()
ORDER BY 
    bdate;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cid</th><th>bdate</th><th>gen</th><th>dwh_create_date</th></tr></thead><tbody><tr><td>AW00012725</td><td>1916-02-10</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00016455</td><td>1917-02-09</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00014841</td><td>1917-06-05</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00018034</td><td>1917-09-20</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00014992</td><td>1918-02-11</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00025527</td><td>1918-11-08</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00016471</td><td>1919-02-14</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00016325</td><td>1919-03-10</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00028743</td><td>1920-11-14</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00024713</td><td>1922-01-02</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00015628</td><td>1922-04-10</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00017640</td><td>1922-06-06</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00021684</td><td>1923-04-14</td><td>n/a</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00025325</td><td>1923-08-16</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00026314</td><td>1923-11-16</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00024035</td><td>1924-10-05</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00025416</td><td>1924-12-03</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00016563</td><td>1925-02-23</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00015074</td><td>1925-08-25</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00019430</td><td>1926-01-10</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00015075</td><td>1926-03-15</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00023190</td><td>1926-09-07</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00015519</td><td>1927-05-10</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00022453</td><td>1927-08-04</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00016568</td><td>1927-08-13</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00020866</td><td>1927-12-01</td><td>n/a</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00020865</td><td>1928-03-19</td><td>n/a</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00014166</td><td>1928-04-09</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00017619</td><td>1928-12-07</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00022629</td><td>1929-01-30</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00013919</td><td>1929-10-21</td><td>Female</td><td>2026-01-05T21:28:24.154Z</td></tr><tr><td>AW00014768</td><td>1929-12-18</td><td>Male</td><td>2026-01-05T21:28:24.154Z</td></tr></tbody></table></div>

-- %% [markdown]
-- #### Data Standardization and Consistency

-- %%
SELECT DISTINCT
    gen
FROM 
    sales_project.silver.erp_cust_az_12;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>gen</th></tr></thead><tbody><tr><td>Male</td></tr><tr><td>Female</td></tr><tr><td>n/a</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Checking `sales_project.bronze.erp_loc_a_101`

-- %% [markdown]
-- #### Data Standardization & Consistency

-- %%
%sql
SELECT DISTINCT
    cntry
FROM
    sales_project.silver.erp_loc_a_101;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cntry</th></tr></thead><tbody><tr><td>United Kingdom</td></tr><tr><td>Australia</td></tr><tr><td>Canada</td></tr><tr><td>France</td></tr><tr><td>United States</td></tr><tr><td>n/a</td></tr><tr><td>Germany</td></tr></tbody></table></div>

-- %% [markdown]
-- ## Checking `sales_project.silver.erp_px_cat_g_1_v_2`

-- %% [markdown]
-- #### Check for unwanted spaces
-- Expectation: no results

-- %%
%sql
SELECT
    *
FROM
    sales_project.silver.erp_px_cat_g_1_v_2
WHERE 
    id != TRIM(id) 
    OR cat != TRIM(cat) 
    OR subcat != TRIM(subcat) 
    OR maintenance != TRIM(maintenance);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>cat</th><th>subcat</th><th>maintenance</th></tr></thead><tbody></tbody></table></div>

-- %% [markdown]
-- #### Data Standardization & Consistency

-- %%
SELECT DISTINCT
    cat
FROM 
    sales_project.silver.erp_px_cat_g_1_v_2;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cat</th></tr></thead><tbody><tr><td>Clothing</td></tr><tr><td>Components</td></tr><tr><td>Accessories</td></tr><tr><td>Bikes</td></tr></tbody></table></div>
