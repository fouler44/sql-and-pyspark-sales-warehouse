# %% [markdown]
# # DDL for silver layer

# %% [markdown]
# This notebook create tables in 'silver' schema, replacing them if they already exist.
#
# > Note: Due to Databricks Free Edition limitations it wasn't possible to add the default value to `dwh_create_date` column

# %% [markdown]
# #### Create the table `sales_project.silver.crm_cust_info`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.silver.crm_cust_info(
  cst_id INT,
  cst_key STRING,
  cst_firstname STRING,
  cst_lastname STRING,
  cst_gndr STRING,
  cst_marital_status STRING,
  cst_create_date DATE,
  dwh_create_date TIMESTAMP
);

# %% [markdown]
# #### Create the table `sales_project.silver.crm_prd_info`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.silver.crm_prd_info(
  prd_id INT,
  cat_id STRING,
  prd_key STRING,
  prd_nm STRING,
  prd_cost INT,
  prd_line STRING,
  prd_start_dt DATE,
  prd_end_dt DATE,
  dwh_create_date TIMESTAMP
);

# %% [markdown]
# #### Create the table `sales_project.silver.crm_sales_details`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.silver.crm_sales_details(
  sls_ord_num STRING,
  sls_prd_key STRING,
  sls_cust_id INT,
  sls_order_dt DATE,
  sls_ship_dt DATE,
  sls_due_dt DATE,
  sls_sales INT,
  sls_quantity INT,
  sls_price INT,
  dwh_create_date TIMESTAMP
);

# %% [markdown]
# #### Create the table `sales_project.silver.erp_loc_a_101`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.silver.erp_loc_a_101(
  cid STRING,
  cntry STRING,
  dwh_create_date TIMESTAMP
);

# %% [markdown]
# #### Create the table `sales_project.silver.erp_cust_az_12`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.silver.erp_cust_az_12(
  cid STRING,
  bdate DATE,
  gen STRING,
  dwh_create_date TIMESTAMP
);

# %% [markdown]
# #### Create the table `sales_project.silver.erp_px_cat_g_1_v_2`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.silver.erp_px_cat_g_1_v_2(
  id STRING,
  cat STRING,
  subcat STRING,
  maintenance STRING,
  dwh_create_date TIMESTAMP
);
