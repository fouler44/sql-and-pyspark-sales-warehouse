# %% [markdown]
# # DDL for bronze layer

# %% [markdown]
# This notebook create tables in 'bronze' schema, replacing them if they already exist.

# %% [markdown]
# #### Create the table `sales_project.bronze.crm_cust_info`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.bronze.crm_cust_info(
  cst_id BIGINT,
  cst_key STRING,
  cst_firstname STRING,
  cst_lastname STRING,
  cst_gndr STRING,
  cst_marital_status STRING,
  cst_create_date DATE
);

# %% [markdown]
# #### Create the table `sales_project.bronze.crm_prd_info`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.bronze.crm_prd_info(
  prd_id BIGINT,
  prd_key STRING,
  prd_nm STRING,
  prd_cost BIGINT,
  prd_line STRING,
  prd_start_dt DATE,
  prd_end_dt DATE
);

# %% [markdown]
# #### Create the table `sales_project.bronze.crm_sales_details`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.bronze.crm_sales_details(
  sls_ord_num STRING,
  sls_prd_key STRING,
  sls_cust_id BIGINT,
  sls_order_dt BIGINT,
  sls_ship_dt BIGINT,
  sls_due_dt BIGINT,
  sls_sales BIGINT,
  sls_quantity BIGINT,
  sls_price BIGINT
);

# %% [markdown]
# #### Create the table `sales_project.bronze.erp_loc_a_101`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.bronze.erp_loc_a_101(
  cid STRING,
  cntry STRING
)

# %% [markdown]
# #### Create the table `sales_project.bronze.erp_cust_az_12`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.bronze.erp_cust_az_12(
  cid STRING,
  bdate DATE,
  gen STRING
)

# %% [markdown]
# #### Create the table `sales_project.bronze.erp_px_cat_g_1_v_2`

# %%
# %sql
CREATE OR REPLACE TABLE sales_project.bronze.erp_px_cat_g_1_v_2(
  id STRING,
  cat STRING,
  subcat STRING,
  maintenance STRING
)
